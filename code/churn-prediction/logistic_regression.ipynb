# %%
from churn_data import ChurnData

# %%
#matplotlib inline
from sklearn.linear_model import LogisticRegression
from sklearn.feature_selection import SelectFromModel
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
data = ChurnData()

# %% [markdown]
# # Train model

# %%
model = LogisticRegression(penalty='l1')
model = model.fit(**data.train)

# %%
data.getScore(model)
# Out:
# Accuracy: 0.7359504132231405
#
# AUC: 0.8064410716746392
#
#              precision    recall  f1-score   support
#
#         0.0       0.78      0.83      0.80      6195
#         1.0       0.65      0.57      0.61      3485
#
# avg / total       0.73      0.74      0.73      9680
#
# Confusion matrix:
#  [[5124 1071]
#  [1485 2000]]
# /home/georg/.anaconda3/envs/tensorflow/lib/python3.5/site-packages/sklearn/metrics/classification.py:105: FutureWarning: np.average currently does not preserve subclasses, but will do so in the future to match the behavior of most other numpy functions such as np.mean. In particular, this means calls which returned a scalar may return a 0-d subclass object instead.
#   return np.average(sample_score, weights=sample_weight)

# %%
featureSelection = SelectFromModel(model, prefit=True)

# %%
pd.DataFrame(list(zip(data.features, model.coef_.reshape(-1), np.abs(model.coef_.reshape(-1)), featureSelection.get_support()))).sort_values(by=2, ascending=False)
# Out:
#                               0         1         2      3
# 37             logDeltaPrev_avg -1.188280  1.188280   True
# 39        logDeltaPrev_wght_avg  1.144312  1.144312   True
# 25               logNumSessions -0.685210  0.685210   True
# 22                      recency  0.573484  0.573484   True
# 30                  numSessions -0.264639  0.264639   True
# 29          dayOfMonth_wght_avg -0.238415  0.238415   True
# 33                    price_avg  0.224737  0.224737   True
# 12               deviceIos_wght -0.157601  0.157601   True
# 3                dayOfMonth_avg  0.156335  0.156335   True
# 38                 logPrice_avg -0.121634  0.121634   True
# 20       logSessionLen_wght_avg  0.120772  0.120772   True
# 1             logSessionLen_avg -0.108177  0.108177   True
# 32       logNumInteractions_avg -0.101995  0.101995   True
# 31          logNumDivisions_avg  0.094895  0.094895   True
# 36      numItemsViewed_wght_avg -0.063913  0.063913   True
# ...

# %% [markdown]
# ## less data

# %%
data2 = ChurnPrediction(features=['recency', 'logNumSessions', 'deltaPrev_wght_avg',
       'logNumDivisions_wght_avg', 'dayOfMonth_wght_avg', 'logSessionLen_avg'])

# %%
model2 = LogisticRegression()
model2 = model.fit(data2.X_train, data2.y_train)

# %%
data2.testModel(model2)
# Out:
# Accuracy: 0.7326446280991735
#
# AUC: 0.8040190230701624
#
#              precision    recall  f1-score   support
#
#         0.0       0.77      0.83      0.80      6195
#         1.0       0.65      0.56      0.60      3485
#
# avg / total       0.73      0.73      0.73      9680
# /home/georg/.anaconda3/envs/tensorflow/lib/python3.5/site-packages/sklearn/metrics/classification.py:105: FutureWarning: np.average currently does not preserve subclasses, but will do so in the future to match the behavior of most other numpy functions such as np.mean. In particular, this means calls which returned a scalar may return a 0-d subclass object instead.
#   return np.average(sample_score, weights=sample_weight)

# %%
model2.coef_
# Out:
# array([[ 0.5986006 , -0.85443853,  0.08535795, -0.00737167, -0.09852607,
#         -0.07638627]])

# %%
featuresByImportance = np.flip(pd.DataFrame(list(zip(data.features, model.coef_.reshape(-1), np.abs(model.coef_.reshape(-1))))).sort_values(by=2)[0], 0).values

# %%
featuresByImportance
# Out:
# array(['deviceDesktop', 'deviceUnknown', 'hourOfDay_wght_avg',
#        'numInteractions_avg', 'dayOfMonth_avg', 'deviceAndroid_wght',
#        'price_wght_avg', 'deviceDesktop_wght', 'price_avg',
#        'logNumItemsViewed_wght_avg', 'logNumInteractions_avg',
#        'logDeltaPrev_avg', 'deviceMobile_wght', 'logPrice_wght_avg',
#        'logNumInteractions_wght_avg', 'sessionLen_avg',
#        'numItemsViewed_avg', 'dayOfWeek_wght_avg', 'deltaPrev_wght_avg',
#        'numDivisions_avg', 'deviceMobile', 'logNumDivisions_wght_avg',
#        'deviceIos_wght', 'logNumSessions', 'deviceAndroid',
#        'sessionLen_wght_avg', 'deviceIos', 'deviceUnknown_wght',
#        'dayOfMonth_wght_avg', 'recency', 'logNumDivisions_avg',
#        'deltaPrev_avg', 'logPrice_avg', 'numDivisions_wght_avg',
#        'numInteractions_wght_avg', 'numItemsViewed_wght_avg',
#        'dayOfWeek_avg', 'logSessionLen_avg', 'logSessionLen_wght_avg',
# ...

# %% [markdown]
# ## Ridge Regression

# %%
from sklearn.linear_model import RidgeClassifier

# %%
data = ChurnData()

# %%
model = RidgeClassifier()

# %%
model.fit(**data.train)
# Out:
# RidgeClassifier(alpha=1.0, class_weight=None, copy_X=True, fit_intercept=True,
#         max_iter=None, normalize=False, random_state=None, solver='auto',
#         tol=0.001)

# %%
pd.DataFrame(list(zip(data.features, model.coef_.reshape(-1), np.abs(model.coef_.reshape(-1))))).sort_values(by=2, ascending=False)
# Out:
#                               0         1         2
# 25               logNumSessions -0.298787  0.298787
# 22                      recency  0.239701  0.239701
# 37             logDeltaPrev_avg -0.190365  0.190365
# 39        logDeltaPrev_wght_avg  0.147151  0.147151
# 41           deltaPrev_wght_avg  0.081611  0.081611
# 33                    price_avg  0.076231  0.076231
# 30                  numSessions  0.056759  0.056759
# 31          logNumDivisions_avg  0.051084  0.051084
# 1             logSessionLen_avg -0.046664  0.046664
# 38                 logPrice_avg -0.044432  0.044432
# 29          dayOfMonth_wght_avg -0.040084  0.040084
# 20       logSessionLen_wght_avg  0.039845  0.039845
# 32       logNumInteractions_avg -0.038401  0.038401
# 8              numDivisions_avg -0.036150  0.036150
# 34   logNumItemsViewed_wght_avg -0.034064  0.034064
# 42                deltaPrev_avg -0.028434  0.028434
# 23        logNumItemsViewed_avg  0.025016  0.025016
# ...
