# %%
# %matplotlib inline
import matplotlib.pyplot as plt

import sys
sys.path.insert(0, '../utils')
from dataPiping import *

import numpy as np
import pandas as pd
import math
import datetime
from sklearn.ensemble import RandomForestRegressor

# %%
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import mean_squared_error
from math import exp, fabs, sqrt, log, pi
import random

# %%
rnd=57
random.seed(rnd)

# %%
X, y = getAggrSet()
X_train, X_test, y_train, y_test = splitAndNormaliseAggr(X,y)
y_train = y_train.values
y_test = y_test.values

# %%
def pltBars(values, labels):
    fig = plt.figure(figsize=(20,5))
    plt.bar(range(len(values)), values)
    plt.xticks(range(len(values)), labels)

# %% [markdown]
# ## Random Forest Regression

# %%
model = RandomForestRegressor()

# %%
param_grid = {
    'max_features': range(1, len(X.columns)+1),
    'n_estimators': [100],
    'max_depth': range(1,25),
    'min_samples_leaf': range(1,20)
}

# %%
grid = RandomizedSearchCV(estimator=model, param_distributions=param_grid, n_iter=100, verbose=2, n_jobs=4)

# %%
grid.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# [CV] max_depth=10, n_estimators=100, max_features=11, min_samples_leaf=17
# [CV] max_depth=10, n_estimators=100, max_features=11, min_samples_leaf=17
# [CV] max_depth=10, n_estimators=100, max_features=11, min_samples_leaf=17
# [CV] max_depth=18, n_estimators=100, max_features=4, min_samples_leaf=11
# [CV]  max_depth=18, n_estimators=100, max_features=4, min_samples_leaf=11, total=   6.1s
# [CV] max_depth=18, n_estimators=100, max_features=4, min_samples_leaf=11
# [CV]  max_depth=10, n_estimators=100, max_features=11, min_samples_leaf=17, total=   8.0s
# [CV] max_depth=18, n_estimators=100, max_features=4, min_samples_leaf=11
# [CV]  max_depth=10, n_estimators=100, max_features=11, min_samples_leaf=17, total=   8.4s
# [CV] max_depth=1, n_estimators=100, max_features=9, min_samples_leaf=2
# [CV]  max_depth=1, n_estimators=100, max_features=9, min_samples_leaf=2, total=   0.9s
# [CV] max_depth=1, n_estimators=100, max_features=9, min_samples_leaf=2
# [CV]  max_depth=1, n_estimators=100, max_features=9, min_samples_leaf=2, total=   0.9s
# [CV] max_depth=1, n_estimators=100, max_features=9, min_samples_leaf=2
# [CV]  max_depth=10, n_estimators=100, max_features=11, min_samples_leaf=17, total=  10.4s
# [CV] max_depth=4, n_estimators=100, max_features=4, min_samples_leaf=5
# [CV]  max_depth=18, n_estimators=100, max_features=4, min_samples_leaf=11, total=   5.0s
# [CV] max_depth=4, n_estimators=100, max_features=4, min_samples_leaf=5
# [CV]  max_depth=1, n_estimators=100, max_features=9, min_samples_leaf=2, total=   1.4s
# [CV] max_depth=4, n_estimators=100, max_features=4, min_samples_leaf=5
# [CV]  max_depth=4, n_estimators=100, max_features=4, min_samples_leaf=5, total=   1.5s
# [CV] max_depth=12, n_estimators=100, max_features=9, min_samples_leaf=15
# [CV]  max_depth=18, n_estimators=100, max_features=4, min_samples_leaf=11, total=   4.4s
# [CV] max_depth=12, n_estimators=100, max_features=9, min_samples_leaf=15
# [CV]  max_depth=4, n_estimators=100, max_features=4, min_samples_leaf=5, total=   1.9s
# [CV] max_depth=12, n_estimators=100, max_features=9, min_samples_leaf=15
# [CV]  max_depth=4, n_estimators=100, max_features=4, min_samples_leaf=5, total=   1.9s
# [CV] max_depth=3, n_estimators=100, max_features=8, min_samples_leaf=9
# [CV]  max_depth=3, n_estimators=100, max_features=8, min_samples_leaf=9, total=   2.2s
# [CV] max_depth=3, n_estimators=100, max_features=8, min_samples_leaf=9
# [CV]  max_depth=3, n_estimators=100, max_features=8, min_samples_leaf=9, total=   2.2s
# [CV] max_depth=3, n_estimators=100, max_features=8, min_samples_leaf=9
# [CV]  max_depth=12, n_estimators=100, max_features=9, min_samples_leaf=15, total=   7.7s
# [CV] max_depth=17, n_estimators=100, max_features=6, min_samples_leaf=6
# [CV]  max_depth=3, n_estimators=100, max_features=8, min_samples_leaf=9, total=   2.2s
# [CV] max_depth=17, n_estimators=100, max_features=6, min_samples_leaf=6
# [CV]  max_depth=12, n_estimators=100, max_features=9, min_samples_leaf=15, total=   7.7s
# [CV] max_depth=17, n_estimators=100, max_features=6, min_samples_leaf=6
# [CV]  max_depth=12, n_estimators=100, max_features=9, min_samples_leaf=15, total=   7.7s
# [CV] max_depth=10, n_estimators=100, max_features=5, min_samples_leaf=19
# [CV]  max_depth=10, n_estimators=100, max_features=5, min_samples_leaf=19, total=   3.9s
# [CV] max_depth=10, n_estimators=100, max_features=5, min_samples_leaf=19
# [CV]  max_depth=17, n_estimators=100, max_features=6, min_samples_leaf=6, total=   6.7s
# [CV] max_depth=10, n_estimators=100, max_features=5, min_samples_leaf=19
# [CV]  max_depth=17, n_estimators=100, max_features=6, min_samples_leaf=6, total=   6.7s
# [CV] max_depth=11, n_estimators=100, max_features=7, min_samples_leaf=12
# [CV]  max_depth=17, n_estimators=100, max_features=6, min_samples_leaf=6, total=   6.7s
# [CV] max_depth=11, n_estimators=100, max_features=7, min_samples_leaf=12
# [CV]  max_depth=10, n_estimators=100, max_features=5, min_samples_leaf=19, total=   4.0s
# [CV] max_depth=11, n_estimators=100, max_features=7, min_samples_leaf=12
# [CV]  max_depth=10, n_estimators=100, max_features=5, min_samples_leaf=19, total=   4.0s
# [CV] max_depth=4, n_estimators=100, max_features=1, min_samples_leaf=7
# [CV]  max_depth=4, n_estimators=100, max_features=1, min_samples_leaf=7, total=   0.6s
# [CV] max_depth=4, n_estimators=100, max_features=1, min_samples_leaf=7
# [CV]  max_depth=4, n_estimators=100, max_features=1, min_samples_leaf=7, total=   0.6s
# [CV] max_depth=4, n_estimators=100, max_features=1, min_samples_leaf=7
# [CV]  max_depth=4, n_estimators=100, max_features=1, min_samples_leaf=7, total=   0.6s
# [CV] max_depth=15, n_estimators=100, max_features=4, min_samples_leaf=3
# [CV]  max_depth=11, n_estimators=100, max_features=7, min_samples_leaf=12, total=   5.9s
# [CV] max_depth=15, n_estimators=100, max_features=4, min_samples_leaf=3
# [CV]  max_depth=11, n_estimators=100, max_features=7, min_samples_leaf=12, total=   5.8s
# [CV] max_depth=15, n_estimators=100, max_features=4, min_samples_leaf=3
# [CV]  max_depth=11, n_estimators=100, max_features=7, min_samples_leaf=12, total=   6.0s
# [CV] max_depth=21, n_estimators=100, max_features=13, min_samples_leaf=11
# [CV]  max_depth=15, n_estimators=100, max_features=4, min_samples_leaf=3, total=   4.6s
# [CV] max_depth=21, n_estimators=100, max_features=13, min_samples_leaf=11
# [CV]  max_depth=15, n_estimators=100, max_features=4, min_samples_leaf=3, total=   5.1s
# [CV] max_depth=21, n_estimators=100, max_features=13, min_samples_leaf=11
# [CV]  max_depth=15, n_estimators=100, max_features=4, min_samples_leaf=3, total=   4.9s
# [CV] max_depth=1, n_estimators=100, max_features=3, min_samples_leaf=2
# [Parallel(n_jobs=4)]: Done  33 tasks      | elapsed:   39.1s
# [CV]  max_depth=1, n_estimators=100, max_features=3, min_samples_leaf=2, total=   0.4s
# [CV] max_depth=1, n_estimators=100, max_features=3, min_samples_leaf=2
# [CV]  max_depth=1, n_estimators=100, max_features=3, min_samples_leaf=2, total=   0.4s
# [CV] max_depth=1, n_estimators=100, max_features=3, min_samples_leaf=2
# [CV]  max_depth=1, n_estimators=100, max_features=3, min_samples_leaf=2, total=   0.4s
# [CV] max_depth=12, n_estimators=100, max_features=2, min_samples_leaf=8
# [CV]  max_depth=12, n_estimators=100, max_features=2, min_samples_leaf=8, total=   2.1s
# [CV] max_depth=12, n_estimators=100, max_features=2, min_samples_leaf=8
# [CV]  max_depth=12, n_estimators=100, max_features=2, min_samples_leaf=8, total=   2.1s
# [CV] max_depth=12, n_estimators=100, max_features=2, min_samples_leaf=8
# [CV]  max_depth=12, n_estimators=100, max_features=2, min_samples_leaf=8, total=   2.1s
# [CV] max_depth=22, n_estimators=100, max_features=2, min_samples_leaf=7
# [CV]  max_depth=21, n_estimators=100, max_features=13, min_samples_leaf=11, total=  12.8s
# [CV] max_depth=22, n_estimators=100, max_features=2, min_samples_leaf=7
# [CV]  max_depth=22, n_estimators=100, max_features=2, min_samples_leaf=7, total=   2.6s
# [CV] max_depth=22, n_estimators=100, max_features=2, min_samples_leaf=7
# [CV]  max_depth=21, n_estimators=100, max_features=13, min_samples_leaf=11, total=  13.0s
# [CV] max_depth=16, n_estimators=100, max_features=2, min_samples_leaf=4
# [CV]  max_depth=21, n_estimators=100, max_features=13, min_samples_leaf=11, total=  13.0s
# [CV] max_depth=16, n_estimators=100, max_features=2, min_samples_leaf=4
# [CV]  max_depth=22, n_estimators=100, max_features=2, min_samples_leaf=7, total=   2.7s
# [CV] max_depth=16, n_estimators=100, max_features=2, min_samples_leaf=4
# [CV]  max_depth=22, n_estimators=100, max_features=2, min_samples_leaf=7, total=   2.7s
# [CV] max_depth=21, n_estimators=100, max_features=10, min_samples_leaf=15
# [CV]  max_depth=16, n_estimators=100, max_features=2, min_samples_leaf=4, total=   2.7s
# [CV] max_depth=21, n_estimators=100, max_features=10, min_samples_leaf=15
# [CV]  max_depth=16, n_estimators=100, max_features=2, min_samples_leaf=4, total=   2.7s
# [CV] max_depth=21, n_estimators=100, max_features=10, min_samples_leaf=15
# [CV]  max_depth=16, n_estimators=100, max_features=2, min_samples_leaf=4, total=   2.7s
# [CV] max_depth=6, n_estimators=100, max_features=8, min_samples_leaf=12
# [CV]  max_depth=6, n_estimators=100, max_features=8, min_samples_leaf=12, total=   4.1s
# [CV] max_depth=6, n_estimators=100, max_features=8, min_samples_leaf=12
# [CV]  max_depth=21, n_estimators=100, max_features=10, min_samples_leaf=15, total=   9.5s
# [CV] max_depth=6, n_estimators=100, max_features=8, min_samples_leaf=12
# [CV]  max_depth=6, n_estimators=100, max_features=8, min_samples_leaf=12, total=   4.1s
# [CV] max_depth=9, n_estimators=100, max_features=12, min_samples_leaf=8
# [CV]  max_depth=21, n_estimators=100, max_features=10, min_samples_leaf=15, total=   9.7s
# [CV] max_depth=9, n_estimators=100, max_features=12, min_samples_leaf=8
# [CV]  max_depth=21, n_estimators=100, max_features=10, min_samples_leaf=15, total=   9.8s
# [CV] max_depth=9, n_estimators=100, max_features=12, min_samples_leaf=8
# [CV]  max_depth=6, n_estimators=100, max_features=8, min_samples_leaf=12, total=   4.1s
# [CV] max_depth=1, n_estimators=100, max_features=13, min_samples_leaf=12
# [CV]  max_depth=1, n_estimators=100, max_features=13, min_samples_leaf=12, total=   1.2s
# [CV] max_depth=1, n_estimators=100, max_features=13, min_samples_leaf=12
# [CV]  max_depth=1, n_estimators=100, max_features=13, min_samples_leaf=12, total=   1.3s
# [CV] max_depth=1, n_estimators=100, max_features=13, min_samples_leaf=12
# [CV]  max_depth=1, n_estimators=100, max_features=13, min_samples_leaf=12, total=   1.3s
# [CV] max_depth=8, n_estimators=100, max_features=7, min_samples_leaf=10
# [CV]  max_depth=9, n_estimators=100, max_features=12, min_samples_leaf=8, total=   8.6s
# [CV] max_depth=8, n_estimators=100, max_features=7, min_samples_leaf=10
# [CV]  max_depth=9, n_estimators=100, max_features=12, min_samples_leaf=8, total=   8.5s
# [CV] max_depth=8, n_estimators=100, max_features=7, min_samples_leaf=10
# [CV]  max_depth=9, n_estimators=100, max_features=12, min_samples_leaf=8, total=   8.5s
# [CV] max_depth=24, n_estimators=100, max_features=2, min_samples_leaf=13
# [CV]  max_depth=8, n_estimators=100, max_features=7, min_samples_leaf=10, total=   4.6s
# [CV] max_depth=24, n_estimators=100, max_features=2, min_samples_leaf=13
# [CV]  max_depth=24, n_estimators=100, max_features=2, min_samples_leaf=13, total=   2.5s
# [CV] max_depth=24, n_estimators=100, max_features=2, min_samples_leaf=13
# [CV]  max_depth=8, n_estimators=100, max_features=7, min_samples_leaf=10, total=   4.6s
# [CV] max_depth=3, n_estimators=100, max_features=2, min_samples_leaf=10
# [CV]  max_depth=3, n_estimators=100, max_features=2, min_samples_leaf=10, total=   0.7s
# [CV] max_depth=3, n_estimators=100, max_features=2, min_samples_leaf=10
# [CV]  max_depth=8, n_estimators=100, max_features=7, min_samples_leaf=10, total=   4.7s
# [CV] max_depth=3, n_estimators=100, max_features=2, min_samples_leaf=10
# [CV]  max_depth=24, n_estimators=100, max_features=2, min_samples_leaf=13, total=   2.5s
# [CV] max_depth=20, n_estimators=100, max_features=10, min_samples_leaf=16
# [CV]  max_depth=3, n_estimators=100, max_features=2, min_samples_leaf=10, total=   0.7s
# [CV] max_depth=20, n_estimators=100, max_features=10, min_samples_leaf=16
# [CV]  max_depth=3, n_estimators=100, max_features=2, min_samples_leaf=10, total=   0.8s
# [CV] max_depth=20, n_estimators=100, max_features=10, min_samples_leaf=16
# [CV]  max_depth=24, n_estimators=100, max_features=2, min_samples_leaf=13, total=   2.5s
# [CV] max_depth=6, n_estimators=100, max_features=4, min_samples_leaf=19
# [CV]  max_depth=6, n_estimators=100, max_features=4, min_samples_leaf=19, total=   2.2s
# [CV] max_depth=6, n_estimators=100, max_features=4, min_samples_leaf=19
# [CV]  max_depth=6, n_estimators=100, max_features=4, min_samples_leaf=19, total=   2.6s
# [CV] max_depth=6, n_estimators=100, max_features=4, min_samples_leaf=19
# [CV]  max_depth=6, n_estimators=100, max_features=4, min_samples_leaf=19, total=   2.1s
# [CV] max_depth=16, n_estimators=100, max_features=6, min_samples_leaf=12
# [CV]  max_depth=20, n_estimators=100, max_features=10, min_samples_leaf=16, total=   9.4s
# [CV] max_depth=16, n_estimators=100, max_features=6, min_samples_leaf=12
# [CV]  max_depth=20, n_estimators=100, max_features=10, min_samples_leaf=16, total=   9.5s
# [CV] max_depth=16, n_estimators=100, max_features=6, min_samples_leaf=12
# [CV]  max_depth=20, n_estimators=100, max_features=10, min_samples_leaf=16, total=  10.0s
# [CV] max_depth=21, n_estimators=100, max_features=13, min_samples_leaf=10
# [CV]  max_depth=16, n_estimators=100, max_features=6, min_samples_leaf=12, total=   6.3s
# [CV] max_depth=21, n_estimators=100, max_features=13, min_samples_leaf=10
# [CV]  max_depth=16, n_estimators=100, max_features=6, min_samples_leaf=12, total=   6.1s
# [CV] max_depth=21, n_estimators=100, max_features=13, min_samples_leaf=10
# [CV]  max_depth=16, n_estimators=100, max_features=6, min_samples_leaf=12, total=   6.3s
# [CV] max_depth=11, n_estimators=100, max_features=6, min_samples_leaf=5
# [CV]  max_depth=11, n_estimators=100, max_features=6, min_samples_leaf=5, total=   5.2s
# [CV] max_depth=11, n_estimators=100, max_features=6, min_samples_leaf=5
# [CV]  max_depth=21, n_estimators=100, max_features=13, min_samples_leaf=10, total=  12.9s
# [CV] max_depth=11, n_estimators=100, max_features=6, min_samples_leaf=5
# [CV]  max_depth=11, n_estimators=100, max_features=6, min_samples_leaf=5, total=   5.3s
# [CV] max_depth=15, n_estimators=100, max_features=7, min_samples_leaf=19
# [CV]  max_depth=21, n_estimators=100, max_features=13, min_samples_leaf=10, total=  13.5s
# [CV] max_depth=15, n_estimators=100, max_features=7, min_samples_leaf=19
# [CV]  max_depth=11, n_estimators=100, max_features=6, min_samples_leaf=5, total=   5.3s
# [CV] max_depth=15, n_estimators=100, max_features=7, min_samples_leaf=19
# [CV]  max_depth=21, n_estimators=100, max_features=13, min_samples_leaf=10, total=  13.3s
# [CV] max_depth=12, n_estimators=100, max_features=12, min_samples_leaf=7
# [CV]  max_depth=15, n_estimators=100, max_features=7, min_samples_leaf=19, total=   6.5s
# [CV] max_depth=12, n_estimators=100, max_features=12, min_samples_leaf=7
# [CV]  max_depth=15, n_estimators=100, max_features=7, min_samples_leaf=19, total=   6.6s
# [CV] max_depth=12, n_estimators=100, max_features=12, min_samples_leaf=7
# [CV]  max_depth=15, n_estimators=100, max_features=7, min_samples_leaf=19, total=   6.5s
# [CV] max_depth=1, n_estimators=100, max_features=10, min_samples_leaf=14
# [CV]  max_depth=1, n_estimators=100, max_features=10, min_samples_leaf=14, total=   1.0s
# [CV] max_depth=1, n_estimators=100, max_features=10, min_samples_leaf=14
# [CV]  max_depth=1, n_estimators=100, max_features=10, min_samples_leaf=14, total=   1.0s
# [CV] max_depth=1, n_estimators=100, max_features=10, min_samples_leaf=14
# [CV]  max_depth=1, n_estimators=100, max_features=10, min_samples_leaf=14, total=   1.0s
# [CV] max_depth=13, n_estimators=100, max_features=8, min_samples_leaf=9
# [CV]  max_depth=12, n_estimators=100, max_features=12, min_samples_leaf=7, total=  10.5s
# [CV] max_depth=13, n_estimators=100, max_features=8, min_samples_leaf=9
# [CV]  max_depth=12, n_estimators=100, max_features=12, min_samples_leaf=7, total=  10.4s
# [CV] max_depth=13, n_estimators=100, max_features=8, min_samples_leaf=9
# [CV]  max_depth=12, n_estimators=100, max_features=12, min_samples_leaf=7, total=  10.9s
# [CV] max_depth=8, n_estimators=100, max_features=8, min_samples_leaf=11
# [CV]  max_depth=13, n_estimators=100, max_features=8, min_samples_leaf=9, total=   7.9s
# [CV] max_depth=8, n_estimators=100, max_features=8, min_samples_leaf=11
# [CV]  max_depth=13, n_estimators=100, max_features=8, min_samples_leaf=9, total=   8.1s
# [CV] max_depth=8, n_estimators=100, max_features=8, min_samples_leaf=11
# [CV]  max_depth=8, n_estimators=100, max_features=8, min_samples_leaf=11, total=   5.6s
# [CV] max_depth=6, n_estimators=100, max_features=2, min_samples_leaf=6
# [CV]  max_depth=13, n_estimators=100, max_features=8, min_samples_leaf=9, total=   7.5s
# [CV] max_depth=6, n_estimators=100, max_features=2, min_samples_leaf=6
# [CV]  max_depth=8, n_estimators=100, max_features=8, min_samples_leaf=11, total=   5.7s
# [CV] max_depth=6, n_estimators=100, max_features=2, min_samples_leaf=6
# [CV]  max_depth=6, n_estimators=100, max_features=2, min_samples_leaf=6, total=   1.2s
# [CV] max_depth=7, n_estimators=100, max_features=12, min_samples_leaf=13
# [CV]  max_depth=8, n_estimators=100, max_features=8, min_samples_leaf=11, total=   5.2s
# [CV] max_depth=7, n_estimators=100, max_features=12, min_samples_leaf=13
# [CV]  max_depth=6, n_estimators=100, max_features=2, min_samples_leaf=6, total=   1.3s
# [CV] max_depth=7, n_estimators=100, max_features=12, min_samples_leaf=13
# [CV]  max_depth=6, n_estimators=100, max_features=2, min_samples_leaf=6, total=   1.3s
# [CV] max_depth=3, n_estimators=100, max_features=9, min_samples_leaf=1
# [CV]  max_depth=3, n_estimators=100, max_features=9, min_samples_leaf=1, total=   2.5s
# [CV] max_depth=3, n_estimators=100, max_features=9, min_samples_leaf=1
# [CV]  max_depth=3, n_estimators=100, max_features=9, min_samples_leaf=1, total=   2.5s
# [CV] max_depth=3, n_estimators=100, max_features=9, min_samples_leaf=1
# [CV]  max_depth=7, n_estimators=100, max_features=12, min_samples_leaf=13, total=   6.9s
# [CV] max_depth=6, n_estimators=100, max_features=12, min_samples_leaf=5
# [CV]  max_depth=7, n_estimators=100, max_features=12, min_samples_leaf=13, total=   6.9s
# [CV] max_depth=6, n_estimators=100, max_features=12, min_samples_leaf=5
# [CV]  max_depth=7, n_estimators=100, max_features=12, min_samples_leaf=13, total=   6.8s
# [CV] max_depth=6, n_estimators=100, max_features=12, min_samples_leaf=5
# [CV]  max_depth=3, n_estimators=100, max_features=9, min_samples_leaf=1, total=   2.7s
# [CV] max_depth=15, n_estimators=100, max_features=8, min_samples_leaf=6
# [CV]  max_depth=6, n_estimators=100, max_features=12, min_samples_leaf=5, total=   6.2s
# [CV] max_depth=15, n_estimators=100, max_features=8, min_samples_leaf=6
# [CV]  max_depth=6, n_estimators=100, max_features=12, min_samples_leaf=5, total=   6.3s
# [CV] max_depth=15, n_estimators=100, max_features=8, min_samples_leaf=6
# [CV]  max_depth=6, n_estimators=100, max_features=12, min_samples_leaf=5, total=   6.9s
# [CV] max_depth=10, n_estimators=100, max_features=13, min_samples_leaf=12
# [CV]  max_depth=15, n_estimators=100, max_features=8, min_samples_leaf=6, total=   8.8s
# [CV] max_depth=10, n_estimators=100, max_features=13, min_samples_leaf=12
# [CV]  max_depth=15, n_estimators=100, max_features=8, min_samples_leaf=6, total=   8.1s
# [CV] max_depth=10, n_estimators=100, max_features=13, min_samples_leaf=12
# [CV]  max_depth=15, n_estimators=100, max_features=8, min_samples_leaf=6, total=   8.1s
# [CV] max_depth=9, n_estimators=100, max_features=2, min_samples_leaf=5
# [CV]  max_depth=9, n_estimators=100, max_features=2, min_samples_leaf=5, total=   1.7s
# [CV] max_depth=9, n_estimators=100, max_features=2, min_samples_leaf=5
# [CV]  max_depth=10, n_estimators=100, max_features=13, min_samples_leaf=12, total=  10.1s
# [CV] max_depth=9, n_estimators=100, max_features=2, min_samples_leaf=5
# [CV]  max_depth=9, n_estimators=100, max_features=2, min_samples_leaf=5, total=   1.7s
# [CV] max_depth=21, n_estimators=100, max_features=7, min_samples_leaf=12
# [CV]  max_depth=9, n_estimators=100, max_features=2, min_samples_leaf=5, total=   1.8s
# [CV] max_depth=21, n_estimators=100, max_features=7, min_samples_leaf=12
# [CV]  max_depth=10, n_estimators=100, max_features=13, min_samples_leaf=12, total=   9.8s
# [CV] max_depth=21, n_estimators=100, max_features=7, min_samples_leaf=12
# [CV]  max_depth=10, n_estimators=100, max_features=13, min_samples_leaf=12, total=  10.0s
# [CV] max_depth=19, n_estimators=100, max_features=12, min_samples_leaf=13
# [CV]  max_depth=21, n_estimators=100, max_features=7, min_samples_leaf=12, total=   7.2s
# [CV] max_depth=19, n_estimators=100, max_features=12, min_samples_leaf=13
# [CV]  max_depth=21, n_estimators=100, max_features=7, min_samples_leaf=12, total=   7.6s
# [CV] max_depth=19, n_estimators=100, max_features=12, min_samples_leaf=13
# [CV]  max_depth=21, n_estimators=100, max_features=7, min_samples_leaf=12, total=   7.6s
# [CV] max_depth=23, n_estimators=100, max_features=9, min_samples_leaf=14
# [CV]  max_depth=19, n_estimators=100, max_features=12, min_samples_leaf=13, total=  11.5s
# [CV] max_depth=23, n_estimators=100, max_features=9, min_samples_leaf=14
# [CV]  max_depth=23, n_estimators=100, max_features=9, min_samples_leaf=14, total=   8.8s
# [CV] max_depth=23, n_estimators=100, max_features=9, min_samples_leaf=14
# [CV]  max_depth=19, n_estimators=100, max_features=12, min_samples_leaf=13, total=  11.6s
# [CV] max_depth=22, n_estimators=100, max_features=4, min_samples_leaf=17
# [CV]  max_depth=19, n_estimators=100, max_features=12, min_samples_leaf=13, total=  11.5s
# [CV] max_depth=22, n_estimators=100, max_features=4, min_samples_leaf=17
# [CV]  max_depth=22, n_estimators=100, max_features=4, min_samples_leaf=17, total=   4.3s
# [CV] max_depth=22, n_estimators=100, max_features=4, min_samples_leaf=17
# [CV]  max_depth=22, n_estimators=100, max_features=4, min_samples_leaf=17, total=   4.2s
# [CV] max_depth=19, n_estimators=100, max_features=5, min_samples_leaf=2
# [CV]  max_depth=23, n_estimators=100, max_features=9, min_samples_leaf=14, total=   8.9s
# [CV] max_depth=19, n_estimators=100, max_features=5, min_samples_leaf=2
# [CV]  max_depth=23, n_estimators=100, max_features=9, min_samples_leaf=14, total=   9.2s
# [CV] max_depth=19, n_estimators=100, max_features=5, min_samples_leaf=2
# [CV]  max_depth=22, n_estimators=100, max_features=4, min_samples_leaf=17, total=   4.2s
# [CV] max_depth=13, n_estimators=100, max_features=8, min_samples_leaf=14
# [CV]  max_depth=19, n_estimators=100, max_features=5, min_samples_leaf=2, total=   6.5s
# [CV] max_depth=13, n_estimators=100, max_features=8, min_samples_leaf=14
# [CV]  max_depth=19, n_estimators=100, max_features=5, min_samples_leaf=2, total=   6.6s
# [CV] max_depth=13, n_estimators=100, max_features=8, min_samples_leaf=14
# [CV]  max_depth=19, n_estimators=100, max_features=5, min_samples_leaf=2, total=   6.5s
# [CV] max_depth=16, n_estimators=100, max_features=11, min_samples_leaf=2
# [CV]  max_depth=13, n_estimators=100, max_features=8, min_samples_leaf=14, total=   7.2s
# [CV] max_depth=16, n_estimators=100, max_features=11, min_samples_leaf=2
# [CV]  max_depth=13, n_estimators=100, max_features=8, min_samples_leaf=14, total=   7.2s
# [CV] max_depth=16, n_estimators=100, max_features=11, min_samples_leaf=2
# [CV]  max_depth=13, n_estimators=100, max_features=8, min_samples_leaf=14, total=   7.2s
# [CV] max_depth=2, n_estimators=100, max_features=5, min_samples_leaf=16
# [CV]  max_depth=2, n_estimators=100, max_features=5, min_samples_leaf=16, total=   1.0s
# [CV] max_depth=2, n_estimators=100, max_features=5, min_samples_leaf=16
# [CV]  max_depth=2, n_estimators=100, max_features=5, min_samples_leaf=16, total=   1.0s
# [CV] max_depth=2, n_estimators=100, max_features=5, min_samples_leaf=16
# [CV]  max_depth=2, n_estimators=100, max_features=5, min_samples_leaf=16, total=   1.0s
# [CV] max_depth=9, n_estimators=100, max_features=6, min_samples_leaf=19
# [CV]  max_depth=16, n_estimators=100, max_features=11, min_samples_leaf=2, total=  12.3s
# [CV] max_depth=9, n_estimators=100, max_features=6, min_samples_leaf=19
# [CV]  max_depth=16, n_estimators=100, max_features=11, min_samples_leaf=2, total=  12.4s
# [CV] max_depth=9, n_estimators=100, max_features=6, min_samples_leaf=19
# [CV]  max_depth=9, n_estimators=100, max_features=6, min_samples_leaf=19, total=   4.3s
# [CV] max_depth=10, n_estimators=100, max_features=5, min_samples_leaf=17
# [CV]  max_depth=16, n_estimators=100, max_features=11, min_samples_leaf=2, total=  12.3s
# [CV] max_depth=10, n_estimators=100, max_features=5, min_samples_leaf=17
# [CV]  max_depth=9, n_estimators=100, max_features=6, min_samples_leaf=19, total=   4.4s
# [CV] max_depth=10, n_estimators=100, max_features=5, min_samples_leaf=17
# [CV]  max_depth=10, n_estimators=100, max_features=5, min_samples_leaf=17, total=   3.9s
# [CV] max_depth=14, n_estimators=100, max_features=10, min_samples_leaf=3
# [CV]  max_depth=9, n_estimators=100, max_features=6, min_samples_leaf=19, total=   4.3s
# [CV] max_depth=14, n_estimators=100, max_features=10, min_samples_leaf=3
# [CV]  max_depth=10, n_estimators=100, max_features=5, min_samples_leaf=17, total=   4.1s
# [CV] max_depth=14, n_estimators=100, max_features=10, min_samples_leaf=3
# [CV]  max_depth=10, n_estimators=100, max_features=5, min_samples_leaf=17, total=   4.0s
# [CV] max_depth=22, n_estimators=100, max_features=3, min_samples_leaf=15
# [CV]  max_depth=22, n_estimators=100, max_features=3, min_samples_leaf=15, total=   3.3s
# [CV] max_depth=22, n_estimators=100, max_features=3, min_samples_leaf=15
# [CV]  max_depth=14, n_estimators=100, max_features=10, min_samples_leaf=3, total=  10.1s
# [CV] max_depth=22, n_estimators=100, max_features=3, min_samples_leaf=15
# [CV]  max_depth=14, n_estimators=100, max_features=10, min_samples_leaf=3, total=  10.2s
# [CV] max_depth=17, n_estimators=100, max_features=3, min_samples_leaf=10
# [CV]  max_depth=22, n_estimators=100, max_features=3, min_samples_leaf=15, total=   3.3s
# [CV] max_depth=17, n_estimators=100, max_features=3, min_samples_leaf=10
# [Parallel(n_jobs=4)]: Done 154 tasks      | elapsed:  3.7min
# [CV]  max_depth=22, n_estimators=100, max_features=3, min_samples_leaf=15, total=   3.3s
# [CV] max_depth=17, n_estimators=100, max_features=3, min_samples_leaf=10
# [CV]  max_depth=14, n_estimators=100, max_features=10, min_samples_leaf=3, total=  10.1s
# [CV] max_depth=11, n_estimators=100, max_features=13, min_samples_leaf=10
# [CV]  max_depth=17, n_estimators=100, max_features=3, min_samples_leaf=10, total=   3.6s
# [CV] max_depth=11, n_estimators=100, max_features=13, min_samples_leaf=10
# [CV]  max_depth=17, n_estimators=100, max_features=3, min_samples_leaf=10, total=   3.4s
# [CV] max_depth=11, n_estimators=100, max_features=13, min_samples_leaf=10
# [CV]  max_depth=17, n_estimators=100, max_features=3, min_samples_leaf=10, total=   3.4s
# [CV] max_depth=14, n_estimators=100, max_features=12, min_samples_leaf=19
# [CV]  max_depth=11, n_estimators=100, max_features=13, min_samples_leaf=10, total=  10.5s
# [CV] max_depth=14, n_estimators=100, max_features=12, min_samples_leaf=19
# [CV]  max_depth=11, n_estimators=100, max_features=13, min_samples_leaf=10, total=  10.4s
# [CV] max_depth=14, n_estimators=100, max_features=12, min_samples_leaf=19
# [CV]  max_depth=11, n_estimators=100, max_features=13, min_samples_leaf=10, total=  10.7s
# [CV] max_depth=17, n_estimators=100, max_features=5, min_samples_leaf=12
# [CV]  max_depth=14, n_estimators=100, max_features=12, min_samples_leaf=19, total=  11.1s
# [CV] max_depth=17, n_estimators=100, max_features=5, min_samples_leaf=12
# [CV]  max_depth=17, n_estimators=100, max_features=5, min_samples_leaf=12, total=   5.4s
# [CV] max_depth=17, n_estimators=100, max_features=5, min_samples_leaf=12
# [CV]  max_depth=17, n_estimators=100, max_features=5, min_samples_leaf=12, total=   5.9s
# [CV] max_depth=22, n_estimators=100, max_features=7, min_samples_leaf=9
# [CV]  max_depth=14, n_estimators=100, max_features=12, min_samples_leaf=19, total=  10.8s
# [CV] max_depth=22, n_estimators=100, max_features=7, min_samples_leaf=9
# [CV]  max_depth=14, n_estimators=100, max_features=12, min_samples_leaf=19, total=  12.0s
# [CV] max_depth=22, n_estimators=100, max_features=7, min_samples_leaf=9
# [CV]  max_depth=17, n_estimators=100, max_features=5, min_samples_leaf=12, total=   6.0s
# [CV] max_depth=12, n_estimators=100, max_features=10, min_samples_leaf=9
# [CV]  max_depth=22, n_estimators=100, max_features=7, min_samples_leaf=9, total=   7.8s
# [CV] max_depth=12, n_estimators=100, max_features=10, min_samples_leaf=9
# [CV]  max_depth=22, n_estimators=100, max_features=7, min_samples_leaf=9, total=   7.7s
# [CV] max_depth=12, n_estimators=100, max_features=10, min_samples_leaf=9
# [CV]  max_depth=22, n_estimators=100, max_features=7, min_samples_leaf=9, total=   8.4s
# [CV] max_depth=11, n_estimators=100, max_features=9, min_samples_leaf=13
# [CV]  max_depth=12, n_estimators=100, max_features=10, min_samples_leaf=9, total=  10.9s
# [CV] max_depth=11, n_estimators=100, max_features=9, min_samples_leaf=13
# [CV]  max_depth=12, n_estimators=100, max_features=10, min_samples_leaf=9, total=   9.6s
# [CV] max_depth=11, n_estimators=100, max_features=9, min_samples_leaf=13
# [CV]  max_depth=11, n_estimators=100, max_features=9, min_samples_leaf=13, total=   8.9s
# [CV] max_depth=11, n_estimators=100, max_features=3, min_samples_leaf=19
# [CV]  max_depth=12, n_estimators=100, max_features=10, min_samples_leaf=9, total=  10.0s
# [CV] max_depth=11, n_estimators=100, max_features=3, min_samples_leaf=19
# [CV]  max_depth=11, n_estimators=100, max_features=3, min_samples_leaf=19, total=   3.1s
# [CV] max_depth=11, n_estimators=100, max_features=3, min_samples_leaf=19
# [CV]  max_depth=11, n_estimators=100, max_features=9, min_samples_leaf=13, total=  10.0s
# [CV] max_depth=16, n_estimators=100, max_features=1, min_samples_leaf=7
# [CV]  max_depth=11, n_estimators=100, max_features=3, min_samples_leaf=19, total=   3.6s
# [CV] max_depth=16, n_estimators=100, max_features=1, min_samples_leaf=7
# [CV]  max_depth=16, n_estimators=100, max_features=1, min_samples_leaf=7, total=   1.7s
# [CV] max_depth=16, n_estimators=100, max_features=1, min_samples_leaf=7
# [CV]  max_depth=11, n_estimators=100, max_features=9, min_samples_leaf=13, total=   7.7s
# [CV] max_depth=24, n_estimators=100, max_features=13, min_samples_leaf=8
# [CV]  max_depth=16, n_estimators=100, max_features=1, min_samples_leaf=7, total=   2.0s
# [CV] max_depth=24, n_estimators=100, max_features=13, min_samples_leaf=8
# [CV]  max_depth=11, n_estimators=100, max_features=3, min_samples_leaf=19, total=   3.9s
# [CV] max_depth=24, n_estimators=100, max_features=13, min_samples_leaf=8
# [CV]  max_depth=16, n_estimators=100, max_features=1, min_samples_leaf=7, total=   1.8s
# [CV] max_depth=12, n_estimators=100, max_features=10, min_samples_leaf=16
# [CV]  max_depth=12, n_estimators=100, max_features=10, min_samples_leaf=16, total=   8.7s
# [CV] max_depth=12, n_estimators=100, max_features=10, min_samples_leaf=16
# [CV]  max_depth=24, n_estimators=100, max_features=13, min_samples_leaf=8, total=  15.2s
# [CV] max_depth=12, n_estimators=100, max_features=10, min_samples_leaf=16
# [CV]  max_depth=24, n_estimators=100, max_features=13, min_samples_leaf=8, total=  16.5s
# [CV] max_depth=10, n_estimators=100, max_features=3, min_samples_leaf=10
# [CV]  max_depth=24, n_estimators=100, max_features=13, min_samples_leaf=8, total=  17.7s
# [CV] max_depth=10, n_estimators=100, max_features=3, min_samples_leaf=10
# [CV]  max_depth=12, n_estimators=100, max_features=10, min_samples_leaf=16, total=   9.2s
# [CV] max_depth=10, n_estimators=100, max_features=3, min_samples_leaf=10
# [CV]  max_depth=10, n_estimators=100, max_features=3, min_samples_leaf=10, total=   3.0s
# [CV] max_depth=23, n_estimators=100, max_features=4, min_samples_leaf=14
# [CV]  max_depth=10, n_estimators=100, max_features=3, min_samples_leaf=10, total=   3.0s
# [CV] max_depth=23, n_estimators=100, max_features=4, min_samples_leaf=14
# [CV]  max_depth=10, n_estimators=100, max_features=3, min_samples_leaf=10, total=   2.9s
# [CV] max_depth=23, n_estimators=100, max_features=4, min_samples_leaf=14
# [CV]  max_depth=23, n_estimators=100, max_features=4, min_samples_leaf=14, total=   4.7s
# [CV] max_depth=15, n_estimators=100, max_features=1, min_samples_leaf=19
# [CV]  max_depth=12, n_estimators=100, max_features=10, min_samples_leaf=16, total=   9.6s
# [CV] max_depth=15, n_estimators=100, max_features=1, min_samples_leaf=19
# [CV]  max_depth=23, n_estimators=100, max_features=4, min_samples_leaf=14, total=   4.6s
# [CV] max_depth=15, n_estimators=100, max_features=1, min_samples_leaf=19
# [CV]  max_depth=15, n_estimators=100, max_features=1, min_samples_leaf=19, total=   1.9s
# [CV] max_depth=8, n_estimators=100, max_features=1, min_samples_leaf=8
# [CV]  max_depth=15, n_estimators=100, max_features=1, min_samples_leaf=19, total=   1.4s
# [CV] max_depth=8, n_estimators=100, max_features=1, min_samples_leaf=8
# [CV]  max_depth=15, n_estimators=100, max_features=1, min_samples_leaf=19, total=   1.9s
# [CV] max_depth=8, n_estimators=100, max_features=1, min_samples_leaf=8
# [CV]  max_depth=23, n_estimators=100, max_features=4, min_samples_leaf=14, total=   4.7s
# [CV] max_depth=3, n_estimators=100, max_features=4, min_samples_leaf=14
# [CV]  max_depth=8, n_estimators=100, max_features=1, min_samples_leaf=8, total=   1.2s
# [CV] max_depth=3, n_estimators=100, max_features=4, min_samples_leaf=14
# [CV]  max_depth=8, n_estimators=100, max_features=1, min_samples_leaf=8, total=   1.3s
# [CV] max_depth=3, n_estimators=100, max_features=4, min_samples_leaf=14
# [CV]  max_depth=8, n_estimators=100, max_features=1, min_samples_leaf=8, total=   1.4s
# [CV] max_depth=4, n_estimators=100, max_features=8, min_samples_leaf=6
# [CV]  max_depth=3, n_estimators=100, max_features=4, min_samples_leaf=14, total=   1.5s
# [CV] max_depth=4, n_estimators=100, max_features=8, min_samples_leaf=6
# [CV]  max_depth=3, n_estimators=100, max_features=4, min_samples_leaf=14, total=   1.6s
# [CV] max_depth=4, n_estimators=100, max_features=8, min_samples_leaf=6
# [CV]  max_depth=3, n_estimators=100, max_features=4, min_samples_leaf=14, total=   1.9s
# [CV] max_depth=12, n_estimators=100, max_features=5, min_samples_leaf=2
# [CV]  max_depth=4, n_estimators=100, max_features=8, min_samples_leaf=6, total=   3.1s
# [CV] max_depth=12, n_estimators=100, max_features=5, min_samples_leaf=2
# [CV]  max_depth=4, n_estimators=100, max_features=8, min_samples_leaf=6, total=   3.4s
# [CV] max_depth=12, n_estimators=100, max_features=5, min_samples_leaf=2
# [CV]  max_depth=4, n_estimators=100, max_features=8, min_samples_leaf=6, total=   3.2s
# [CV] max_depth=24, n_estimators=100, max_features=8, min_samples_leaf=1
# [CV]  max_depth=12, n_estimators=100, max_features=5, min_samples_leaf=2, total=   5.3s
# [CV] max_depth=24, n_estimators=100, max_features=8, min_samples_leaf=1
# [CV]  max_depth=12, n_estimators=100, max_features=5, min_samples_leaf=2, total=   4.9s
# [CV] max_depth=24, n_estimators=100, max_features=8, min_samples_leaf=1
# [CV]  max_depth=12, n_estimators=100, max_features=5, min_samples_leaf=2, total=   5.0s
# [CV] max_depth=10, n_estimators=100, max_features=8, min_samples_leaf=1
# [CV]  max_depth=10, n_estimators=100, max_features=8, min_samples_leaf=1, total=   6.3s
# [CV] max_depth=10, n_estimators=100, max_features=8, min_samples_leaf=1
# [CV]  max_depth=24, n_estimators=100, max_features=8, min_samples_leaf=1, total=  12.2s
# [CV] max_depth=10, n_estimators=100, max_features=8, min_samples_leaf=1
# [CV]  max_depth=24, n_estimators=100, max_features=8, min_samples_leaf=1, total=  11.9s
# [CV] max_depth=20, n_estimators=100, max_features=7, min_samples_leaf=14
# [CV]  max_depth=24, n_estimators=100, max_features=8, min_samples_leaf=1, total=  11.8s
# [CV] max_depth=20, n_estimators=100, max_features=7, min_samples_leaf=14
# [CV]  max_depth=10, n_estimators=100, max_features=8, min_samples_leaf=1, total=   7.8s
# [CV] max_depth=20, n_estimators=100, max_features=7, min_samples_leaf=14
# [CV]  max_depth=10, n_estimators=100, max_features=8, min_samples_leaf=1, total=   7.2s
# [CV] max_depth=8, n_estimators=100, max_features=1, min_samples_leaf=14
# [CV]  max_depth=8, n_estimators=100, max_features=1, min_samples_leaf=14, total=   1.0s
# [CV] max_depth=8, n_estimators=100, max_features=1, min_samples_leaf=14
# [CV]  max_depth=8, n_estimators=100, max_features=1, min_samples_leaf=14, total=   1.0s
# [CV] max_depth=8, n_estimators=100, max_features=1, min_samples_leaf=14
# [CV]  max_depth=20, n_estimators=100, max_features=7, min_samples_leaf=14, total=   7.0s
# [CV] max_depth=15, n_estimators=100, max_features=2, min_samples_leaf=12
# [CV]  max_depth=8, n_estimators=100, max_features=1, min_samples_leaf=14, total=   1.0s
# [CV] max_depth=15, n_estimators=100, max_features=2, min_samples_leaf=12
# [CV]  max_depth=20, n_estimators=100, max_features=7, min_samples_leaf=14, total=   7.1s
# [CV] max_depth=15, n_estimators=100, max_features=2, min_samples_leaf=12
# [CV]  max_depth=15, n_estimators=100, max_features=2, min_samples_leaf=12, total=   2.3s
# [CV] max_depth=2, n_estimators=100, max_features=11, min_samples_leaf=16
# [CV]  max_depth=15, n_estimators=100, max_features=2, min_samples_leaf=12, total=   2.4s
# [CV] max_depth=2, n_estimators=100, max_features=11, min_samples_leaf=16
# [CV]  max_depth=15, n_estimators=100, max_features=2, min_samples_leaf=12, total=   2.3s
# [CV] max_depth=2, n_estimators=100, max_features=11, min_samples_leaf=16
# [CV]  max_depth=20, n_estimators=100, max_features=7, min_samples_leaf=14, total=   7.1s
# [CV] max_depth=15, n_estimators=100, max_features=11, min_samples_leaf=7
# [CV]  max_depth=2, n_estimators=100, max_features=11, min_samples_leaf=16, total=   2.1s
# [CV] max_depth=15, n_estimators=100, max_features=11, min_samples_leaf=7
# [CV]  max_depth=2, n_estimators=100, max_features=11, min_samples_leaf=16, total=   2.1s
# [CV] max_depth=15, n_estimators=100, max_features=11, min_samples_leaf=7
# [CV]  max_depth=2, n_estimators=100, max_features=11, min_samples_leaf=16, total=   2.0s
# [CV] max_depth=4, n_estimators=100, max_features=3, min_samples_leaf=18
# [CV]  max_depth=4, n_estimators=100, max_features=3, min_samples_leaf=18, total=   1.2s
# [CV] max_depth=4, n_estimators=100, max_features=3, min_samples_leaf=18
# [CV]  max_depth=4, n_estimators=100, max_features=3, min_samples_leaf=18, total=   1.2s
# [CV] max_depth=4, n_estimators=100, max_features=3, min_samples_leaf=18
# [CV]  max_depth=4, n_estimators=100, max_features=3, min_samples_leaf=18, total=   1.2s
# [CV] max_depth=18, n_estimators=100, max_features=9, min_samples_leaf=3
# [CV]  max_depth=15, n_estimators=100, max_features=11, min_samples_leaf=7, total=  10.9s
# [CV] max_depth=18, n_estimators=100, max_features=9, min_samples_leaf=3
# [CV]  max_depth=15, n_estimators=100, max_features=11, min_samples_leaf=7, total=  10.9s
# [CV] max_depth=18, n_estimators=100, max_features=9, min_samples_leaf=3
# [CV]  max_depth=15, n_estimators=100, max_features=11, min_samples_leaf=7, total=  10.9s
# [CV] max_depth=17, n_estimators=100, max_features=2, min_samples_leaf=19
# [CV]  max_depth=17, n_estimators=100, max_features=2, min_samples_leaf=19, total=   2.2s
# [CV] max_depth=17, n_estimators=100, max_features=2, min_samples_leaf=19
# [CV]  max_depth=18, n_estimators=100, max_features=9, min_samples_leaf=3, total=  10.5s
# [CV] max_depth=17, n_estimators=100, max_features=2, min_samples_leaf=19
# [CV]  max_depth=17, n_estimators=100, max_features=2, min_samples_leaf=19, total=   2.2s
# [CV] max_depth=2, n_estimators=100, max_features=2, min_samples_leaf=15
# [CV]  max_depth=2, n_estimators=100, max_features=2, min_samples_leaf=15, total=   0.5s
# [CV] max_depth=2, n_estimators=100, max_features=2, min_samples_leaf=15
# [CV]  max_depth=17, n_estimators=100, max_features=2, min_samples_leaf=19, total=   2.3s
# [CV] max_depth=2, n_estimators=100, max_features=2, min_samples_leaf=15
# [CV]  max_depth=2, n_estimators=100, max_features=2, min_samples_leaf=15, total=   0.5s
# [CV] max_depth=24, n_estimators=100, max_features=12, min_samples_leaf=8
# [CV]  max_depth=2, n_estimators=100, max_features=2, min_samples_leaf=15, total=   0.5s
# [CV] max_depth=24, n_estimators=100, max_features=12, min_samples_leaf=8
# [CV]  max_depth=18, n_estimators=100, max_features=9, min_samples_leaf=3, total=  10.7s
# [CV] max_depth=24, n_estimators=100, max_features=12, min_samples_leaf=8
# [CV]  max_depth=18, n_estimators=100, max_features=9, min_samples_leaf=3, total=  10.6s
# [CV] max_depth=11, n_estimators=100, max_features=7, min_samples_leaf=19
# [CV]  max_depth=11, n_estimators=100, max_features=7, min_samples_leaf=19, total=   5.7s
# [CV] max_depth=11, n_estimators=100, max_features=7, min_samples_leaf=19
# [CV]  max_depth=24, n_estimators=100, max_features=12, min_samples_leaf=8, total=  12.7s
# [CV] max_depth=11, n_estimators=100, max_features=7, min_samples_leaf=19
# [CV]  max_depth=24, n_estimators=100, max_features=12, min_samples_leaf=8, total=  12.8s
# [CV] max_depth=2, n_estimators=100, max_features=9, min_samples_leaf=12
# [CV]  max_depth=2, n_estimators=100, max_features=9, min_samples_leaf=12, total=   1.7s
# [CV] max_depth=2, n_estimators=100, max_features=9, min_samples_leaf=12
# [CV]  max_depth=11, n_estimators=100, max_features=7, min_samples_leaf=19, total=   5.7s
# [CV] max_depth=2, n_estimators=100, max_features=9, min_samples_leaf=12
# [CV]  max_depth=24, n_estimators=100, max_features=12, min_samples_leaf=8, total=  13.0s
# [CV] max_depth=19, n_estimators=100, max_features=1, min_samples_leaf=16
# [CV]  max_depth=2, n_estimators=100, max_features=9, min_samples_leaf=12, total=   1.7s
# [CV] max_depth=19, n_estimators=100, max_features=1, min_samples_leaf=16
# [CV]  max_depth=2, n_estimators=100, max_features=9, min_samples_leaf=12, total=   2.0s
# [CV] max_depth=19, n_estimators=100, max_features=1, min_samples_leaf=16
# [CV]  max_depth=19, n_estimators=100, max_features=1, min_samples_leaf=16, total=   2.2s
# [CV] max_depth=20, n_estimators=100, max_features=13, min_samples_leaf=4
# [CV]  max_depth=19, n_estimators=100, max_features=1, min_samples_leaf=16, total=   1.5s
# [CV] max_depth=20, n_estimators=100, max_features=13, min_samples_leaf=4
# [CV]  max_depth=11, n_estimators=100, max_features=7, min_samples_leaf=19, total=   5.7s
# [CV] max_depth=20, n_estimators=100, max_features=13, min_samples_leaf=4
# [CV]  max_depth=19, n_estimators=100, max_features=1, min_samples_leaf=16, total=   2.0s
# [CV] max_depth=16, n_estimators=100, max_features=1, min_samples_leaf=6
# [CV]  max_depth=16, n_estimators=100, max_features=1, min_samples_leaf=6, total=   1.6s
# [CV] max_depth=16, n_estimators=100, max_features=1, min_samples_leaf=6
# [CV]  max_depth=16, n_estimators=100, max_features=1, min_samples_leaf=6, total=   1.6s
# [CV] max_depth=16, n_estimators=100, max_features=1, min_samples_leaf=6
# [CV]  max_depth=16, n_estimators=100, max_features=1, min_samples_leaf=6, total=   1.6s
# [CV] max_depth=24, n_estimators=100, max_features=1, min_samples_leaf=19
# [CV]  max_depth=24, n_estimators=100, max_features=1, min_samples_leaf=19, total=   1.4s
# [CV] max_depth=24, n_estimators=100, max_features=1, min_samples_leaf=19
# [CV]  max_depth=24, n_estimators=100, max_features=1, min_samples_leaf=19, total=   1.5s
# [CV] max_depth=24, n_estimators=100, max_features=1, min_samples_leaf=19
# [CV]  max_depth=24, n_estimators=100, max_features=1, min_samples_leaf=19, total=   1.4s
# [CV] max_depth=20, n_estimators=100, max_features=9, min_samples_leaf=6
# [CV]  max_depth=20, n_estimators=100, max_features=13, min_samples_leaf=4, total=  14.9s
# [CV] max_depth=20, n_estimators=100, max_features=9, min_samples_leaf=6
# [CV]  max_depth=20, n_estimators=100, max_features=13, min_samples_leaf=4, total=  14.8s
# [CV] max_depth=20, n_estimators=100, max_features=9, min_samples_leaf=6
# [CV]  max_depth=20, n_estimators=100, max_features=13, min_samples_leaf=4, total=  15.2s
# [CV] max_depth=5, n_estimators=100, max_features=7, min_samples_leaf=14
# [CV]  max_depth=5, n_estimators=100, max_features=7, min_samples_leaf=14, total=   3.7s
# [CV] max_depth=5, n_estimators=100, max_features=7, min_samples_leaf=14
# [CV]  max_depth=20, n_estimators=100, max_features=9, min_samples_leaf=6, total=  10.7s
# [CV] max_depth=5, n_estimators=100, max_features=7, min_samples_leaf=14
# [CV]  max_depth=5, n_estimators=100, max_features=7, min_samples_leaf=14, total=   3.1s
# [CV] max_depth=16, n_estimators=100, max_features=8, min_samples_leaf=5
# [CV]  max_depth=5, n_estimators=100, max_features=7, min_samples_leaf=14, total=   3.0s
# [CV] max_depth=16, n_estimators=100, max_features=8, min_samples_leaf=5
# [CV]  max_depth=20, n_estimators=100, max_features=9, min_samples_leaf=6, total=   9.9s
# [CV] max_depth=16, n_estimators=100, max_features=8, min_samples_leaf=5
# [CV]  max_depth=20, n_estimators=100, max_features=9, min_samples_leaf=6, total=   9.9s
# [CV] max_depth=17, n_estimators=100, max_features=10, min_samples_leaf=14
# [CV]  max_depth=16, n_estimators=100, max_features=8, min_samples_leaf=5, total=   8.5s
# [CV] max_depth=17, n_estimators=100, max_features=10, min_samples_leaf=14
# [CV]  max_depth=16, n_estimators=100, max_features=8, min_samples_leaf=5, total=   8.7s
# [CV] max_depth=17, n_estimators=100, max_features=10, min_samples_leaf=14
# [CV]  max_depth=16, n_estimators=100, max_features=8, min_samples_leaf=5, total=   8.5s
# [CV] max_depth=23, n_estimators=100, max_features=9, min_samples_leaf=1
# [CV]  max_depth=17, n_estimators=100, max_features=10, min_samples_leaf=14, total=   9.5s
# [CV] max_depth=23, n_estimators=100, max_features=9, min_samples_leaf=1
# [CV]  max_depth=17, n_estimators=100, max_features=10, min_samples_leaf=14, total=   9.8s
# [CV] max_depth=23, n_estimators=100, max_features=9, min_samples_leaf=1
# [CV]  max_depth=17, n_estimators=100, max_features=10, min_samples_leaf=14, total=   9.8s
# [CV] max_depth=7, n_estimators=100, max_features=7, min_samples_leaf=10
# [CV]  max_depth=23, n_estimators=100, max_features=9, min_samples_leaf=1, total=  13.2s
# [CV] max_depth=7, n_estimators=100, max_features=7, min_samples_leaf=10
# [CV]  max_depth=7, n_estimators=100, max_features=7, min_samples_leaf=10, total=   4.4s
# [CV] max_depth=7, n_estimators=100, max_features=7, min_samples_leaf=10
# [CV]  max_depth=23, n_estimators=100, max_features=9, min_samples_leaf=1, total=  13.5s
# [CV] max_depth=9, n_estimators=100, max_features=2, min_samples_leaf=16
# [CV]  max_depth=9, n_estimators=100, max_features=2, min_samples_leaf=16, total=   1.8s
# [CV] max_depth=9, n_estimators=100, max_features=2, min_samples_leaf=16
# [CV]  max_depth=7, n_estimators=100, max_features=7, min_samples_leaf=10, total=   4.3s
# [CV] max_depth=9, n_estimators=100, max_features=2, min_samples_leaf=16
# [CV]  max_depth=7, n_estimators=100, max_features=7, min_samples_leaf=10, total=   4.2s
# [CV] max_depth=22, n_estimators=100, max_features=9, min_samples_leaf=12
# [CV]  max_depth=9, n_estimators=100, max_features=2, min_samples_leaf=16, total=   1.9s
# [CV] max_depth=22, n_estimators=100, max_features=9, min_samples_leaf=12
# [CV]  max_depth=9, n_estimators=100, max_features=2, min_samples_leaf=16, total=   1.7s
# [CV] max_depth=22, n_estimators=100, max_features=9, min_samples_leaf=12
# [CV]  max_depth=23, n_estimators=100, max_features=9, min_samples_leaf=1, total=  13.7s
# [CV] max_depth=3, n_estimators=100, max_features=8, min_samples_leaf=15
# [CV]  max_depth=3, n_estimators=100, max_features=8, min_samples_leaf=15, total=   2.2s
# [CV] max_depth=3, n_estimators=100, max_features=8, min_samples_leaf=15
# [CV]  max_depth=3, n_estimators=100, max_features=8, min_samples_leaf=15, total=   3.1s
# [CV] max_depth=3, n_estimators=100, max_features=8, min_samples_leaf=15
# [CV]  max_depth=22, n_estimators=100, max_features=9, min_samples_leaf=12, total=   9.5s
# [CV] max_depth=21, n_estimators=100, max_features=6, min_samples_leaf=4
# [CV]  max_depth=22, n_estimators=100, max_features=9, min_samples_leaf=12, total=   9.8s
# [CV] max_depth=21, n_estimators=100, max_features=6, min_samples_leaf=4
# [CV]  max_depth=3, n_estimators=100, max_features=8, min_samples_leaf=15, total=   2.3s
# [CV] max_depth=21, n_estimators=100, max_features=6, min_samples_leaf=4
# [CV]  max_depth=22, n_estimators=100, max_features=9, min_samples_leaf=12, total=   9.0s
# [CV] max_depth=10, n_estimators=100, max_features=9, min_samples_leaf=14
# [CV]  max_depth=10, n_estimators=100, max_features=9, min_samples_leaf=14, total=   6.9s
# [CV] max_depth=10, n_estimators=100, max_features=9, min_samples_leaf=14
# [CV]  max_depth=21, n_estimators=100, max_features=6, min_samples_leaf=4, total=   7.6s
# [CV] max_depth=10, n_estimators=100, max_features=9, min_samples_leaf=14
# [CV]  max_depth=21, n_estimators=100, max_features=6, min_samples_leaf=4, total=   7.4s
# [CV] max_depth=21, n_estimators=100, max_features=3, min_samples_leaf=8
# [CV]  max_depth=21, n_estimators=100, max_features=6, min_samples_leaf=4, total=   7.4s
# [CV] max_depth=21, n_estimators=100, max_features=3, min_samples_leaf=8
# [CV]  max_depth=21, n_estimators=100, max_features=3, min_samples_leaf=8, total=   3.8s
# [CV] max_depth=21, n_estimators=100, max_features=3, min_samples_leaf=8
# [CV]  max_depth=21, n_estimators=100, max_features=3, min_samples_leaf=8, total=   4.2s
# [CV]  max_depth=10, n_estimators=100, max_features=9, min_samples_leaf=14, total=   6.7s
# [CV]  max_depth=10, n_estimators=100, max_features=9, min_samples_leaf=14, total=   7.6s
# [CV]  max_depth=21, n_estimators=100, max_features=3, min_samples_leaf=8, total=   3.6s
# [Parallel(n_jobs=4)]: Done 300 out of 300 | elapsed:  7.5min finished
# RandomizedSearchCV(cv=None, error_score='raise',
#           estimator=RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_split=1e-07, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=10, n_jobs=1, oob_score=False, random_state=None,
#            verbose=0, warm_start=False),
#           fit_params={}, iid=True, n_iter=100, n_jobs=4,
#           param_distributions={'max_depth': range(1, 25), 'n_estimators': [100], 'max_features': range(1, 14), 'min_samples_leaf': range(1, 20)},
#           pre_dispatch='2*n_jobs', random_state=None, refit=True,
#           return_train_score=True, scoring=None, verbose=2)

# %%
grid.best_params_
# Out:
# {'max_depth': 8,
#  'max_features': 8,
#  'min_samples_leaf': 11,
#  'n_estimators': 100}

# %%
rf = RandomForestRegressor(**grid.best_params_)

# %%
rf.fit(X_train, y_train)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=8,
#            max_features=8, max_leaf_nodes=None, min_impurity_split=1e-07,
#            min_samples_leaf=11, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=1,
#            oob_score=False, random_state=None, verbose=0, warm_start=False)

# %%
pltBars(rf.feature_importances_, X.columns)

# %%
rmse = sqrt(mean_squared_error(y_test, rf.predict(X_test)))
str(datetime.timedelta(seconds=rmse))
# Out:
# '71 days, 13:32:26.038420'
